# %% [markdown]
# <a href="https://colab.research.google.com/github/SuanTay/P3/blob/master/2_2HIDE_mergeNG%26NS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import missingno as msno
dfNG = pd.read_csv('/content/drive/My Drive/Colab Notebooks/fr.openfoodfacts.org.products.csv/mergeNG.knn.nutriscore.fr.clean.lowfeatures.openfoodfacts.org.products.csv', sep='\t', low_memory=False)
dfNS = pd.read_csv('/content/drive/My Drive/Colab Notebooks/fr.openfoodfacts.org.products.csv/mergeNS.knn.nutriscore.fr.clean.lowfeatures.openfoodfacts.org.products.csv', sep='\t', low_memory=False)

# %%
dfNG.columns
# Out:
# Index(['Unnamed: 0', 'code', 'energy_100g', 'fat_100g', 'saturated-fat_100g',
#        'carbohydrates_100g', 'sugars_100g', 'fiber_100g', 'proteins_100g',
#        'salt_100g', 'sodium_100g', 'nutriscore_grade'],
#       dtype='object')

# %%
dfNS.columns
# Out:
# Index(['Unnamed: 0', 'code', 'energy_100g', 'fat_100g', 'saturated-fat_100g',
#        'carbohydrates_100g', 'sugars_100g', 'fiber_100g', 'proteins_100g',
#        'salt_100g', 'sodium_100g', 'nutriscore_score'],
#       dtype='object')

# %%
df =pd.merge ( dfNG, dfNS , on=['code', 'energy_100g', 'fat_100g', 'saturated-fat_100g',
       'carbohydrates_100g', 'sugars_100g', 'fiber_100g', 'proteins_100g',
       'salt_100g', 'sodium_100g'])

# %%
df.columns
# Out:
# Index(['Unnamed: 0_x', 'code', 'energy_100g', 'fat_100g', 'saturated-fat_100g',
#        'carbohydrates_100g', 'sugars_100g', 'fiber_100g', 'proteins_100g',
#        'salt_100g', 'sodium_100g', 'nutriscore_grade', 'Unnamed: 0_y',
#        'nutriscore_score'],
#       dtype='object')

# %%
df.drop(columns= ['Unnamed: 0_x','Unnamed: 0_y'],inplace=True)
#df2 = df2.rename(columns={'nutriscore_grade_y': 'nutriscore_grade'})
msno.matrix(df)

# %%
df.to_csv('/content/drive/My Drive/Colab Notebooks/fr.openfoodfacts.org.products.csv/openfoodfacts.csv',sep='\t', encoding='utf-8', header=True)

# %%
len(df)
# Out:
# 530285

# %% [markdown]
# Ajouter pnn_group2

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/fr.openfoodfacts.org.products.csv/fr.openfoodfacts.org.products.csv',sep='\t',  low_memory=False)
data=data[['code', 'url', 'product_name', 'pnns_groups_2',
       'energy_100g', 'fat_100g', 'saturated-fat_100g', 'carbohydrates_100g',
       'sugars_100g', 'fiber_100g', 'proteins_100g', 'salt_100g',
       'sodium_100g']]

# %%
len(data)
# Out:
# 1424453

# %%
bdf =pd.merge ( df, data , on=['code'])

# %%
len(bdf.columns)
# Out:
# 15

# %%
bdf.drop(columns= [ 'energy_100g_y', 'fat_100g_y', 'saturated-fat_100g_y',
       'carbohydrates_100g_y', 'sugars_100g_y', 'fiber_100g_y',
       'proteins_100g_y', 'salt_100g_y', 'sodium_100g_y'],inplace=True)
bdf = bdf.rename(columns={'energy_100g_x':'energy_100g', 'fat_100g_x':'fat_100g', 'saturated-fat_100g_x':'saturated-fat_100g',
       'carbohydrates_100g_x':'carbohydrates_100g', 'sugars_100g_x':'sugars_100g', 'fiber_100g_x':'fiber_100g',
       'proteins_100g_x':'proteins_100g', 'salt_100g_x':'salt_100g', 'sodium_100g_x':'sodium_100g',})

# %%
len(bdf)
# Out:
# 530286

# %%
msno.bar(bdf)

# %%
bdf.columns
# Out:
# Index(['code', 'energy_100g', 'fat_100g', 'saturated-fat_100g',
#        'carbohydrates_100g', 'sugars_100g', 'fiber_100g', 'proteins_100g',
#        'salt_100g', 'sodium_100g', 'nutriscore_grade', 'nutriscore_score',
#        'url', 'product_name', 'pnns_groups_2'],
#       dtype='object')

# %%
data=bdf[['code','url','product_name','pnns_groups_2','energy_100g', 'fat_100g', 'saturated-fat_100g',
     'carbohydrates_100g', 'sugars_100g', 'fiber_100g','proteins_100g','salt_100g', 'sodium_100g','nutriscore_grade','nutriscore_score']]

# %%
data.to_csv('/content/drive/My Drive/Colab Notebooks/fr.openfoodfacts.org.products.csv/openfoodfacts.csv',sep='\t', encoding='utf-8', header=True)

# %%
data.columns
# Out:
# Index(['code', 'url', 'product_name', 'pnns_groups_2', 'energy_100g',
#        'fat_100g', 'saturated-fat_100g', 'carbohydrates_100g', 'sugars_100g',
#        'fiber_100g', 'proteins_100g', 'salt_100g', 'sodium_100g',
#        'nutriscore_grade', 'nutriscore_score'],
#       dtype='object')

# %%
msno.bar(data)
